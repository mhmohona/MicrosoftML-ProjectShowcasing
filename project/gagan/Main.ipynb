# %% [markdown]
# ## Imports

# %%
import pandas as pd

from face_tagging.visualization import visualize
from face_tagging.model import FaceTaggingModel

# %% [markdown]
# ## Constants

# %%
TRAIN_IMAGES_DIR = "resources/train_images"
WORKFLOW_IMAGES_DIR = "resources/workflow"
TRAIN_DF_DIR = "resources/csv/key_points.csv"

# %%
df = pd.read_csv(TRAIN_DF_DIR)
df.head()
# Out:
#     Unnamed: 0         0         1         2         3         4         5  \
# 0   image2.jpg -0.185909  0.067868  0.039309 -0.082200 -0.086981  0.039979
# 1  image10.jpg -0.163997  0.032625  0.132290 -0.138209 -0.069839 -0.088106
# 2   image4.jpg -0.155427  0.047399  0.005643  0.037812 -0.044404 -0.068241
# 3   image6.jpg -0.005563  0.016488  0.036630 -0.125987 -0.078083  0.022831
# 4   image8.jpg -0.159116  0.025757  0.089369 -0.116362 -0.129103 -0.065410
#
#           6         7         8  ...       118       119       120       121  \
# 0 -0.029991 -0.057583  0.140435  ...  0.081886 -0.026868  0.062151 -0.064383
# 1 -0.052248 -0.176265  0.139457  ...  0.048913  0.044040  0.067779 -0.062480
# 2 -0.026556 -0.203503  0.097148  ...  0.081202  0.079869  0.000999  0.040762
# 3 -0.038736 -0.041771  0.222424  ...  0.065053  0.047178  0.099247  0.113197
# 4 -0.058841 -0.124685  0.174449  ...  0.074093  0.030151  0.085750 -0.088163
#
# ...

# %%
df = df.set_index('Unnamed: 0')
df.head(2)
# Out:
#                     0         1         2         3         4         5  \
# Unnamed: 0
# image2.jpg  -0.185909  0.067868  0.039309 -0.082200 -0.086981  0.039979
# image10.jpg -0.163997  0.032625  0.132290 -0.138209 -0.069839 -0.088106
#
#                     6         7         8         9  ...       118       119  \
# Unnamed: 0                                           ...
# image2.jpg  -0.029991 -0.057583  0.140435 -0.143214  ...  0.081886 -0.026868
# image10.jpg -0.052248 -0.176265  0.139457 -0.155102  ...  0.048913  0.044040
#
#                   120       121       122       123       124       125  \
# Unnamed: 0
# image2.jpg   0.062151 -0.064383 -0.144577 -0.184796  0.064035 -0.082566
# image10.jpg  0.067779 -0.062480 -0.095175 -0.077019  0.047777 -0.089953
#
#                   126       127
# Unnamed: 0
# image2.jpg   0.167055  0.036307
# image10.jpg  0.064141  0.026908
#
# [2 rows x 128 columns]

# %%
obj_model = FaceTaggingModel(keypoints_df=df, train_images_path=TRAIN_IMAGES_DIR)

# %%
obj_model.train_model(silent=True)
# Out:
# 7it [00:00, 196.05it/s]Trained

# %%
result = obj_model.matched_groups(); result
# Out:
# {0: array(['image2.jpg'], dtype='<U10'),
#  1: array(['image10.jpg', 'image8.jpg', 'image9.jpg'], dtype=object),
#  2: array(['image4.jpg', 'image1.jpg'], dtype=object),
#  3: array(['image6.jpg'], dtype='<U10')}

# %%
visualize(result, TRAIN_IMAGES_DIR)

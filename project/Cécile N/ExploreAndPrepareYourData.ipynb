# %% [markdown]
# # Explore and prepare your data
#
# ## Reminder - What are the data ?
# ___
#
# The data I will use in this project are the [Titanic dataset from kaggle](https://www.kaggle.com/c/titanic/data).
#
# On this web page there is a data description with an overwiew explaining the datasets and the data dictionary:
#
#
# ![Image of the data dictionary](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-10%2023_32_05-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)
#
# ![img overview of data](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-11%2000_02_21-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)

# %% [markdown]
# ## What means explore and prepare your data ?
#
# ### Steps to follow
# ___
#
# - Explore the data
#
#
# - Prepare the data
#
#
# #### Why explore the data ?
# ___
#
# Exploring the data will enable you to better know the inputs data (independent features) and their quality:
#
#  - Their **type** : numerical (discrete, continuous), categorical (numerical, ordinal, nominal)  [a little reminder if necessary 🙂](https://github.com/NAVERGONI/MicrosoftML-ProjectShowcasing/blob/master/project/C%C3%A9cile%20N/AnalyzeTheProblem.ipynb)
#
#  - What are their **meaning** (e.g.: where did a passenger embark)?
#
#  - Are the values all **distinct** ? Is there a limited amount of distinct values ?
#
#  - Is there **missing values** ? If there is missing values is it just some or a lot ?
#
#  - Is there **outliers** ?
#
#  - Are some independent features **correlated** ?
#
#
# #### Exploration of our data
# ___
#
# First you need to have the dataset you want to explore in your "DATASETS" section and add it to an experiment:
#
# ![Datasets](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasets.jpg)
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_experiment.jpg)
#
# Then you can right-click on the dataset module and choose the "dataset -> Visualize" menu
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasetVisualization.jpg)
#
# It will show you a resume of your dataset (number of rows and columns) and it will allow you to have statistics on each column of your dataset by selecting the column
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasetVisualizationDetails_note.jpg)
#
#
# #### What can we learn about our data with this exploration ?
# ___
#
# We have 891 rows and 12 columns. In plain text this mean there was 891 passengers on the Titanic and for each passenger we have 12 different informations.
#
# The visualization gives us statistics about each feature (column):
#
# |  | Feature Type | Unique Values | Missing Values | Mean | Median | Min | Max | Standard Deviation |
# |--|--|--|--|--|--|--|--|--|
# |PassengerId  | Numeric | 891 | 0 | 446 | 446 | 1 | 891 | 257.35  |
# |Survived | Numeric | 2 | 0 | 0.38 | 0 | 0 | 1 | 0.49 |
# |Pclass | Numeric | 3 | 0 | 2.3 | 3 | 1 | 3 | 0.84 |
# |Name | String | 891 | 0 |  |  |  |  |  |
# |Sex | String | 2 | 0 |  |  |  |  |  |
# |Age | Numeric | 88 | **177** | 29.7 | 28 | 0.42 | 80 | 14.53 |
# |SibSp | Numeric | 7 | 0 | 0.52 | 0 | 0 | 8 | 1.10 |
# |Parch | Numeric | 7 | 0 | 0.38 | 0 | 0 | 6 | 0.81 |
# |Ticket | String | 681 | 0 |  |  |  |  |  |
# |Fare | Numeric | 248 | 0 | 32.20 | 14.45 | 0 | 512.32 | 49.69 |
# |Cabin | String | 147 | **687** |  |  |  |  |  |
# |Embarked | String | 3 | **2** |  |  |  |  |  |
#
# We also have the frequency chart for each feature. Some are not interesting for us (e.g.:all feature where there is as many different values as there are rows => PassengerId, Name) but others can teach us a lot !
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TitanicDataset_FrequencyCharts.jpg)
#
# #### What did we learn with this exploration and what can we do ?
# ___
#
#   - There is two features for which all values are unique: PassegerId and Name => we can drop this columns
#
#
#   - There is three features with missing values:
#
#
#     - Cabin: there is 687 missing values. This is too much => we will drop this column
#
#     - Age: there is 177 missing values. We can decide a strategy to replace them => as this is an age we can replace them by the mean.
#
#     - Embarked: there is only two missing values. As there is only three different unique values for this feature, we can replace the missing values by the most frequent value that is "S" (for Southampton)
#
# #### Implementation
# ___
#
# To do this we will use Data Transformation moduls:
#
#   - [Select Columns in Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/studio-module-reference/select-columns-in-dataset)
#
#   - [Clean Missing Data](https://docs.microsoft.com/en-us/azure/machine-learning/studio-module-reference/clean-missing-data)
#
# Here are the implementation:
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep1.jpg)
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep3.jpg)
#
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep2.jpg)
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep5.jpg)
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep4.jpg)
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/DataPrep6.jpg)
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/ExecDataPrep.jpg)
#
# As you can see below, now there is only 9 columns instead of 12 after we dropped the 3 columns PassengerID, Name and Cabin
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/ExecDataPrep2.jpg)
#
# And also there is no more missing values 🙂
#
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/ExecDataPrep3.jpg)
#
# **And now the new evaluation of our model which is way better than when we didn't do any data preparation 😀**
# ![Frequency charts](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/ResDataPrep.jpg)
#
# for the record below is the first result:
#
# ![logistic regression raw results](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TwoClassClassif_LogReg_Titanic_Raw_evalResult.png)

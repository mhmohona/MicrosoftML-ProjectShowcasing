# %% [markdown]
# # Explore and prepare your data
#
# ## Reminder - What are the data ?
#
# The data I will use in this project are the [Titanic dataset from kaggle](https://www.kaggle.com/c/titanic/data).
#
# On this web page there is a data description with an overwiew explaining the datasets and the data dictionary :
#
#
# ![Image of the data dictionary](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-10%2023_32_05-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)
#
# ![img overview of data](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-11%2000_02_21-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)

# %% [markdown]
# ## What means explore and prepare your data ?
#
# ### Steps to follow
# ___
#
# - Explore the data
#
#
# - Prepare the data:
#
#
#      - cleaning
#      - restructuration
#      - feature engineering
#      - feature selection
#
#
# #### Why explore the data ?
# ___
#
# Exploring the data will enable you to better know the inputs data (independent features) and their quality:
#
#  - Their **type** : numerical (discrete, continuous), categorical (numerical, ordinal, nominal)  [a little reminder if necessary 🙂](https://github.com/NAVERGONI/MicrosoftML-ProjectShowcasing/blob/master/project/C%C3%A9cile%20N/AnalyzeTheProblem.ipynb)
#
#  - What are their **meaning** (e.g.: where did a passenger embark)?
#
#  - Are the values all **distinct** ? Is there a limited amount of distinct values ?
#
#  - Is there **missing values** ? If there is missing values is it just some or a lot ?
#
#  - Is there **outliers** ?
#
#  - Are some independent features **correlated** ?
#
#
# #### Exploration of our data
# ___
#
# ##### With Microsoft Azure Machine Learning Studio (classic)
# ___
#
# First you need to have the dataset you want to explore in your "DATASETS" section and add it to an experiment:
#
# ![Datasets](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasets.jpg)
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_experiment.jpg)
#
# Then you can right-click on the dataset module and choose the "dataset -> Visualize" menu
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasetVisualization.jpg)
#
# It will show you a resume of your dataset (number of rows and columns) and it will allow you to have statistics on each column of your dataset by selecting the column
#
# ![Experiment](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureMLStudio_datasetVisualizationDetails_note.jpg)
#
#
#
# ##### With a Jupyter Notebook and Python
# ___
#
# ##### 👷‍♀️ This section is under construction. Please be patient 🙂
#
# ##### Wath we can learn about our data with this exploration
# ___
#
# We have 891 rows and 12 columns. In plain text this mean there was 891 passengers on the Titanic and for each passenger we have 12 different informations.
#
# The visualization gives us statistics about each feature (column):
#
# |  | Feature Type | Unique Values | Missing Values | Mean | Median | Min | Max | Standard Deviation |
# |--|--|--|--|--|--|--|--|--|
# |PassengerId  | Numeric | 891 | 0 | 446 | 446 | 1 | 891 | 257.35  |
# |Survived | Numeric | 2 | 0 | 0.38 | 0 | 0 | 1 | 0.49 |
# |Pclass | Numeric | 3 | 0 | 2.3 | 3 | 1 | 3 | 0.84 |
# |Name | String | 891 | 0 |  |  |  |  |  |
# |Sex | String | 2 | 0 |  |  |  |  |  |
# |Age | Numeric | 88 | **177** | 29.7 | 28 | 0.42 | 80 | 14.53 |
# |SibSp | Numeric | 7 | 0 | 0.52 | 0 | 0 | 8 | 1.10 |
# |Parch | Numeric | 7 | 0 | 0.38 | 0 | 0 | 6 | 0.81 |
# |Ticket | String | 681 | 0 |  |  |  |  |  |
# |Fare | Numeric | 248 | 0 | 32.20 | 14.45 | 0 | 512.32 | 49.69 |
# |Cabin | String | 147 | **687** |  |  |  |  |  |
# |Embarked | String | 3 | **2** |  |  |  |  |  |
#
# We have also the frequency chart for each feature. Some are not interesting for us (e.g.:all feature where there is as many different values as there are lines => PassengerId, Name) but others can teach us a lot !
#
#
#
#
#
#  -
#
# ❗️❗️❗️ to be continued ❗️❗️❗️

# %% [markdown]
# # Analyze the type of problem you are facing
#
# ## What are the data ?
#
# The data I will use in this project are the [Titanic dataset from kaggle](https://www.kaggle.com/c/titanic/data).
#
# On this web page there is a data description with an overwiew explaining the datasets and the data dictionary :
#
#
# ![Image of the data dictionary](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-10%2023_32_05-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)
#
# ![img overview of data](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/2020-09-11%2000_02_21-Titanic_%20Machine%20Learning%20from%20Disaster%20_%20Kaggle.png)
#
#
# ## What is the goal ?
#
# The goal is to predict if a passenger **did survive or not** using the known features as sex, age, ...
#
#
# ## What are we facing in terms of Machine Learning vocabulary ?
#
# ### The different types of approaches
#
# There are three main approaches to machine learning :
#
# - Supervised learning : learns from data that contains both the inputs **AND** expected outputs
#
# - Unsupervised learning : learns from data that contains only inputs and finds hidden structures in data
#
# - Reinforcement learning : learns how an agent should take actions in an environment to maximize a reward function
#
# In the Titanic dataset *we know if a person survived or not* => **we have the inputs** (age, sex, ...) **AND** the **expected outputs** (survival = 0 or 1).
#
# So we can say that our approach to this problem is a **supervised** one.
#
# ### The different types of data
#
# There is two main types of data :
#
# 1. Quantitative data (Numerical data)
#
# 2. Qualitative data (Categorical data)
#
# sources used for the creation of the visuals about quantitative and qualitative data:
#
# https://www.dummies.com/education/math/statistics/types-of-statistical-data-numerical-categorical-and-ordinal/
#
# https://www.freecodecamp.org/news/types-of-data-in-statistics-nominal-ordinal-interval-and-ratio-data-types-explained-with-examples/

# %% [markdown]
# #### Quantitative data (Numerical data)
# ![Quantitative data](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TypeOfData_Quantitative.jpg)

# %% [markdown]
# #### Qualtitative data (Numerical data)
# ![Qualitative data](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TypeOfData_Qualitative.jpg)

# %% [markdown]
#
# ***
#
#
# > Our problem is a **supervised** one where the feature we want to predict (expected output) is a **Qualitative Data (Categorical data)**
#
# ### Lets dive deeper into Qualitative Data (Categorical Data)
# ___
#
#
# Below you can see the visual I created for the visual challenge in the **__Microsoft Azure ML Scholarship__**.
#
# It shows that there is three types of Qualitative Data (Categorical Data) classifications:
#
# - **Two-class** classification => used when the expected output is a Categorical Data that has only two distinct values
#
#
# - **Multi-class single-label** classification => used when the expected output for an instance (an item) has more than two possible output values but is described by one and only one value (eg. : the item **is** a banana)
#
#
# - **Multi-class multi-label** classification => used when the expected output for an instance (an item) has more than two possible output values and is described by one or more values (eg. : the item **contains** banana **and** peach)
#
# ___
#
#
# ![Categorical Data and Classification](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/CategoricalData_Classification.jpg)

# %% [markdown]
# ***
#
#
# > Our problem is a **supervised** one where the feature we want to predict (expected output) is a **Qualitative Data (Categorical data)** with two possible output values (Survival = 0 or Survival = 1) so we are facing a **Two-class classification** problem.
#
# ### Lets dive deeper into Two-class classification
# ___
#
#
# Above you can see that there is different types of algorithm we can use when facing a **two-class classification** problem (in no particular order):
#
#
# - Support Vector Machine
#
#
# - Average Perceptron
#
#
# - Decision Forest
#
#
# - Logistic Regression
#
#
# - Boosted Decision Tree
#
#
# - Neural Network
#
#
# For now we will look at the simpliest algorithm for Two-class classification that is **Logistic Regression**
#
# ### What are the metrics for classification problems ?
#
#
# The visual below has been created by Ankur Mutha
# ![classif metrics](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AzureML_Classif_Metrics_Ankur_Mutha.png)
#
#
# ### Lets dive deeper into Logistic Regression
# ___
#
# sources:
#
#   - https://kambria.io/blog/logistic-regression-for-machine-learning/
#
#   - https://stackoverflow.com/questions/12146914/what-is-the-difference-between-linear-regression-and-logistic-regression
#
#   - https://www.javatpoint.com/logistic-regression-in-machine-learning
#
#
# ![Logistic Regression](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/logistic%20regression.jpg)
#
#
#
# ### Evaluate the model performance: confusion matrix, ROC, AUC
# ___
#
#
# As there was a lot of really great visuals on confusion matrix issued during the visual challenge event hosted by UDACITY during the Microsoft Azure ML Scholarship course, I will not create my own visual 🙂
#
# #### 👍🏻 **The following visuals have been created by Kashfia Faruque**
#
#
# ![Confusion matrix precision](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/precision_Kashfia.PNG)
#
#
# ![Confusion matrix recall](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/recall_Kashfia.PNG)
#
#
# #### 👍🏻 **and this one by Ramreddy**
#
#
# ![Confusion matrix and metrics](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/MetricsForClassifModel_AzureML_Ramreddy.png)
#
# #### 👍🏻 **and this is my own**
#
# sources:
#
#   - https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/
#
#   - https://www.displayr.com/what-is-a-roc-curve-how-to-interpret-it/
#
#   - https://medium.com/datadriveninvestor/understanding-auc-roc-clearly-explained-74c53d292a02
#
#
# ![Confusion matrix and metrics](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/AUC_and_ROC_curve.jpg)

# %% [markdown]
# ## Now that we have all the theory lets get concrete
# ___
#
#
# For the purpose of the exercise I will train, score and evaluate the simpliest classifier model (Logistic Regression) without any data preparation, feature selection, feature engineering, or hyper-parameter tunning 😄
#
# I chose the "**Microsoft Azure Machine Learning Studio (classic)**" environment to implement this process. I didn't change any default parameter for the different moduls.
#
#
# ![logistic regression raw](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TwoClassClassif_LogReg_Titanic_Raw.png)
#
#
# ![logistic regression raw results](https://raw.githubusercontent.com/NAVERGONI/MicrosoftML-ProjectShowcasing/master/project/C%C3%A9cile%20N/images/TwoClassClassif_LogReg_Titanic_Raw_evalResult.png)
#
#
# As you can see the ROC curve is above the 0.5 threshold and AUC = 0.737. If you remember what we have learned above about ROC curve and AUC, this result is not bad as it is above the random probability of 0.5
#
# Not bad for an experience where we  trained, scored and evaluated the simpliest classifier model without any data preparation, feature selection, feature engineering, or hyper-parameter tunning 😊.

# %% [markdown]
# __________________________________________________________________________________________________________________
#
# #### This is all for this first Notebook. I hope it has helped you as much as it has helped me to grasp the basic concepts involved in classification problems.
#
#
# #### In the next Notebook I will detail the different steps about Data exploration and preparation.
